# %%
import numpy as np
import pandas as pd

import j_acquire
import j_prep

data = j_acquire.scrape_github_data('repo_source')
df = pd.DataFrame.from_dict(data)
df = df.dropna()
df
# Out:
#                                          repo          language  \
# 1              tokyo-metropolitan-gov/covid19               Vue
# 3             covid19india/covid19india-react        JavaScript
# 5            ieee8023/covid-chestxray-dataset  Jupyter Notebook
# 7                       ahmadawais/corona-cli        JavaScript
# 8            ExpDev07/coronavirus-tracker-api            Python
# 9                  neherlab/covid19_scenarios        TypeScript
# 10                              geohot/corona            Python
# 11        soroushchehresa/awesome-coronavirus        JavaScript
# 12                    mhdhejazi/CoronaTracker             Swift
# 13                             pomber/covid19        JavaScript
# 14                   github/covid19-dashboard  Jupyter Notebook
# 15                          datasets/covid-19            Python
# 16                  chrismattmann/tika-python            Python
# 17         ImperialCollegeLondon/covid19model  Jupyter Notebook
# ...

# %%
# Out:
# (26, 3)
