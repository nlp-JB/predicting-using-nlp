# %%
import numpy as np
import pandas as pd

import nltk

from sklearn.feature_extraction.text import TfidfVectorizer

import j_acquire
import j_prep

# %%
data = j_acquire.scrape_github_data('repo_source')
df = pd.DataFrame.from_dict(data)
df = df.dropna().reset_index()
df
# Out:
#     index                                       repo          language  \
# 0       1             tokyo-metropolitan-gov/covid19               Vue
# 1       3            covid19india/covid19india-react        JavaScript
# 2       5           ieee8023/covid-chestxray-dataset  Jupyter Notebook
# 3       7                      ahmadawais/corona-cli        JavaScript
# 4       8           ExpDev07/coronavirus-tracker-api            Python
# 5       9                 neherlab/covid19_scenarios        TypeScript
# 6      10                              geohot/corona            Python
# 7      11        soroushchehresa/awesome-coronavirus        JavaScript
# 8      12                    mhdhejazi/CoronaTracker             Swift
# 9      13                             pomber/covid19        JavaScript
# 10     14                   github/covid19-dashboard  Jupyter Notebook
# 11     15                          datasets/covid-19            Python
# 12     16                  chrismattmann/tika-python            Python
# 13     17         ImperialCollegeLondon/covid19model  Jupyter Notebook
# 14     18                         owid/covid-19-data            Python
# 15     19                       lindawangg/COVID-Net            Python
# 16     20  globalcitizen/2019-wuhan-coronavirus-data               PHP
# 17     21                         UCSD-AI4H/COVID-CT  Jupyter Notebook
# 18     22                      javieraviles/covidAPI        JavaScript
# 19     23              MohGovIL/hamagen-react-native        TypeScript
# 20     24                   phildini/stayinghomeclub              Ruby
# 21     25                         AaronWard/covidify  Jupyter Notebook
# 22     26                     GuangchuangYu/nCov2019                 R
# 23     27               covidatlas/coronadatascraper              HTML
# 24     28                       ryansmcgee/seirsplus            Python
# 25     29                          lispczz/pneumonia        JavaScript
#
#                                       readme_contents
# 0   # 東京都 新型コロナウイルス感染症対策サイト\n\n![](https://github....
# 1   <p align="center">\n<img src="https://lh3.goog...
# 2   \n#### 🛑 Note: please do not claim diagnostic ...
# 3   <h4 align="center">\n    <a href="https://gith...
# 4   <h1 align="center">\n    Coronavirus Tracker A...
# 5   <h1 id="covid19_scenarios" align="center">\n  ...
# 6   # Reverse engineering the coronavirus (SARS-Co...
# 7   <div align="center">\n\t<br>\n\t<img src="http...
# 8   <img src="https://user-images.githubuserconten...
# 9   Transforms the data from [CSSEGISandData/COVID...
# 10  [//]: # (This template replaces README.md when...
# 11  Coronavirus disease 2019 (COVID-19) time serie...
# 12  [![Build Status](https://travis-ci.org/chrisma...
# 13  ![](https://github.com/ImperialCollegeLondon/c...
# 14  <h3 align="center">\n  Find our data on COVID-...
# 15  # COVID-Net Open Source Initiative\n\n**Note: ...
# 16  # 2019 Wuhan Coronavirus data (COVID-19 / 2019...
# 17  # COVID-CT\n\n\n### The utility of this datase...
# 18  # COVID API\nAPI for live information about CO...
# 19  # Hamagen\n![Build](https://github.com/MohGovI...
# 20  # Who's staying home because of COVID-19?\n\nT...
# 21  # covidify  [![PyPi Version](https://img.shiel...
# 22  # nCov2019: An R package with real-time data, ...
# 23  # THIS PROJECT IS BEING REPLACED BY `Li`\n\n**...
# 24  # SEIRS+ Model\n\nThis package implements gene...
# 25  # 中国新型冠状病毒肺炎疫情地级市图\n\n在网页上通过腾讯新闻的 API 获得 __现存_...

# %%
df = j_prep.prep_readme_data(df)
df.head()
# Out:
#    index                              repo          language  \
# 0      1    tokyo-metropolitan-gov/covid19               Vue
# 1      3   covid19india/covid19india-react        JavaScript
# 2      5  ieee8023/covid-chestxray-dataset  Jupyter Notebook
# 3      7             ahmadawais/corona-cli        JavaScript
# 4      8  ExpDev07/coronavirus-tracker-api            Python
#
#                                      readme_contents  \
# 0  # 東京都 新型コロナウイルス感染症対策サイト\n\n![](https://github....
# 1  <p align="center">\n<img src="https://lh3.goog...
# 2  \n#### 🛑 Note: please do not claim diagnostic ...
# 3  <h4 align="center">\n    <a href="https://gith...
# 4  <h1 align="center">\n    Coronavirus Tracker A...
#
#                                          basic_clean  \
# 0    \n\nhttpsgithubcomtokyometropolitangovcovid1...
# 1  \n\n\n\n\n  heres our data api\n \n\n setup\n\...
# 2  \n  note please do not claim diagnostic perfor...
# 3  \n    \n        \n    \n    \n    \n\ntrack th...
# 4  \n    coronavirus tracker api\n\n\nprovides up...
#
#                                          clean_tokes  \
# 0  [httpsgithubcomtokyometropolitangovcovid19work...
# 1  [heres, our, data, api, setup, npm, i, npm, st...
# 2  [note, please, do, not, claim, diagnostic, per...
# 3  [track, the, coronavirus, disease, covid19, or...
# 4  [coronavirus, tracker, api, provides, uptodate...
#
#                                           lemmatized  \
# 0  httpsgithubcomtokyometropolitangovcovid19workf...
# 1  here our data api setup npm i npm start mainta...
# 2  note please do not claim diagnostic performanc...
# 3  track the coronavirus disease covid19 or the n...
# 4  coronavirus tracker api provides uptodate data...
#
#                                     clean_lemmatized  link_counts
# 0  httpsgithubcomtokyometropolitangovcovid19workf...         1822
# 1  data api setup npm npm start maintainer jeremy...         1822
# 2  note please claim diagnostic performance model...         1822
# 3  track coronavirus disease covid19 novel corona...         1822
# 4  coronavirus tracker api provides uptodate data...         1822

# %%
df.language.value_counts()
# Out:
# Python              7
# JavaScript          6
# Jupyter Notebook    5
# TypeScript          2
# Ruby                1
# Vue                 1
# HTML                1
# R                   1
# PHP                 1
# Swift               1
# Name: language, dtype: int64

# %%
# Lets group all the languages with < 3 as other
# In this part, I want to combine each of the individual strings for each language into one long string
# Then I can count all the words that occur in each language

python_words = ' '.join(df[df.language == 'Python'].clean_lemmatized)
java_words = ' '.join(df[df.language == 'JavaScript'].clean_lemmatized)
jupyter_words = ' '.join(df[df.language == 'Jupyter Notebook'].clean_lemmatized)
other_words = ' '.join(df[(df.language != 'Jupyter Notebook') 
                          & (df.language != 'Python') & (df.language != 'JavaScript')].clean_lemmatized)
all_words = ' '.join(df.clean_lemmatized)

# %%
tokenizer = nltk.tokenize.ToktokTokenizer()

python_words_freq = tokenizer.tokenize(python_words)
java_words_freq = tokenizer.tokenize(java_words)
jupyter_words_freq = tokenizer.tokenize(jupyter_words)
other_words_freq = tokenizer.tokenize(other_words)
all_words_freq = tokenizer.tokenize(all_words)

# %%
python_words_freq = pd.Series(python_words_freq).value_counts()
java_words_freq = pd.Series(java_words_freq).value_counts()
jupyter_words_freq = pd.Series(jupyter_words_freq).value_counts()
other_words_freq = pd.Series(other_words_freq).value_counts()
all_words_freq = pd.Series(all_words_freq).value_counts()

# %%
python_words_freq
# Out:
# model                                               95
# individual                                          76
# network                                             70
# rate                                                65
# tika                                                52
#                                                     ..
# bioinformatics                                       1
# investigate                                          1
# redocshttpscoronavirustrackerapiherokuappcomdocs     1
# darpa                                                1
# cumulative                                           1
# Length: 2100, dtype: int64

# %%
word_counts = (pd.concat([all_words_freq, python_words_freq, java_words_freq, 
                          jupyter_words_freq, other_words_freq], axis=1, sort=True)
              .set_axis(['all', 'python', 'java', 'jupyter', 'other'], axis=1, inplace=False)
              .fillna(0)
              .apply(lambda s: s.astype(int)))

word_counts.head()
# Out:
#      all  python  java  jupyter  other
# 0     58      48    10        0      0
# 00    28       0     0       28      0
# 002    8       8     0        0      0
# 01     4       4     0        0      0
# 02     8       8     0        0      0

# %%
word_counts.sort_values(by='all', ascending=False).head(10)
# Out:
#              all  python  java  jupyter  other
# covid19      436      37   359       21     19
# data         290      44   143       34     69
# coronavirus  224      15   195        1     13
# case         158      47    86       15     10
# country      136      11    97       18     10
# model        134      95    11       17     11
# source        81      20    31        7     23
# individual    79      76     1        1      1
# rate          73      65     7        0      1
# number        72      36    23        8      5

# %%
word_counts.sort_values(by='python', ascending=False).head(10)
# Out:
#             all  python  java  jupyter  other
# model       134      95    11       17     11
# individual   79      76     1        1      1
# network      70      70     0        0      0
# rate         73      65     7        0      1
# tika         52      52     0        0      0
# parameter    71      49     2        1     19
# 0            58      48    10        0      0
# case        158      47    86       15     10
# data        290      44   143       34     69
# time         72      43    23        3      3

# %%
tfidf = TfidfVectorizer()
tfidfs = tfidf.fit_transform(df.clean_lemmatized)
vectorized_df = pd.DataFrame(tfidfs.todense(), columns=tfidf.get_feature_names())
vectorized_df
# Out:
#           00       002        01        02  04162020        05  05132020  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.630423  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.014731  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.024351  0.000000  0.024351
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.048331  0.016084  0.048331  0.000000  0.012083  0.000000
# 25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#     05262020  06012020       0no  ...      zero     zhang      zhao   zhidong  \
# 0   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.022515  ...  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.019723
# 4   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  ...  0.021284  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.011862  0.000000
# 13  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 15  0.024351  0.024351  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  ...  0.000000  0.110067  0.032560  0.000000
# 18  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  ...  0.016084  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#        zhong      zhou      zinc  zingming      zoom       zum
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.150628  0.000000  0.000000  0.000000
# 7   0.000000  0.006085  0.000000  0.000000  0.000000  0.006085
# 8   0.000000  0.000000  0.000000  0.000000  0.108472  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.011377  0.000000
# 10  0.000000  0.000000  0.000000  0.091685  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.048702  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [26 rows x 5388 columns]

# %%
len(set(tokenizer.tokenize(df.clean_lemmatized.iloc[2])))
# Out:
# 384

# %%
tokenizer.tokenize(df.clean_lemmatized.iloc[2])
# Out:
# ['note',
#  'please',
#  'claim',
#  'diagnostic',
#  'performance',
#  'model',
#  'without',
#  'clinical',
#  'study',
#  'kaggle',
#  'competition',
#  'dataset',
#  'please',
#  'read',
#  'paper',
#  'evaluation',
#  'issue',
#  'httpsarxivorgabs200412823httpsarxivorgabs200412823',
#  'covid19',
#  'image',
#  'data',
#  'collection',
#  'video',
#  'projecthttpswwwyoutubecomwatchvinewmqfeleq',
#  'project',
#  'summary',
#  'build',
#  'public',
#  'open',
#  'dataset',
#  'chest',
#  'xray',
#  'ct',
#  'image',
#  'patient',
#  'positive',
#  'suspected',
#  'covid19',
#  'viral',
#  'bacterial',
#  'pneumonia',
#  'mershttpsenwikipediaorgwikimiddle_east_respiratory_syndrome',
#  'sarshttpsenwikipediaorgwikisevere_acute_respiratory_syndrome',
#  'ardshttpsenwikipediaorgwikiacute_respiratory_distress_syndrome',
#  'data',
#  'collected',
#  'public',
#  'source',
#  'well',
#  'indirect',
#  'collection',
#  'hospital',
#  'physician',
#  'image',
#  'data',
#  'released',
#  'publicly',
#  'github',
#  'repo',
#  'project',
#  'approved',
#  'university',
#  'montreal',
#  'ethic',
#  'committee',
#  'cerses20058d',
#  'view',
#  'current',
#  'imagesimages',
#  'metadatametadatacsv',
#  'current',
#  'stats',
#  'pa',
#  'ap',
#  'ap',
#  'supine',
#  'view',
#  'label',
#  '0no',
#  '1yes',
#  'data',
#  'loader',
#  'herehttpsgithubcommlmedtorchxrayvisionblobmastertorchxrayvisiondatasetspyl867',
#  'covid19_dataset',
#  'num_samples328',
#  'viewspa',
#  'ap',
#  'ards',
#  '00',
#  '313',
#  '10',
#  '15',
#  'bacterial',
#  'pneumonia',
#  '00',
#  '304',
#  '10',
#  '24',
#  'covid19',
#  '00',
#  '78',
#  '10',
#  '250',
#  'chlamydophila',
#  '00',
#  '327',
#  '10',
#  '1',
#  'fungal',
#  'pneumonia',
#  '00',
#  '316',
#  '10',
#  '12',
#  'klebsiella',
#  '00',
#  '321',
#  '10',
#  '7',
#  'legionella',
#  '00',
#  '325',
#  '10',
#  '3',
#  'mers',
#  '00',
#  '328',
#  'finding',
#  '00',
#  '316',
#  '10',
#  '12',
#  'pneumocystis',
#  '00',
#  '316',
#  '10',
#  '12',
#  'pneumonia',
#  '00',
#  '19',
#  '10',
#  '309',
#  'sars',
#  '00',
#  '312',
#  '10',
#  '16',
#  'streptococcus',
#  '00',
#  '315',
#  '10',
#  '13',
#  'viral',
#  'pneumonia',
#  '00',
#  '62',
#  '10',
#  '266',
#  'covid19_dataset',
#  'num_samples90',
#  'viewsap',
#  'supine',
#  'ards',
#  '00',
#  '89',
#  '10',
#  '1',
#  'bacterial',
#  'pneumonia',
#  '00',
#  '90',
#  'covid19',
#  '00',
#  '9',
#  '10',
#  '81',
#  'chlamydophila',
#  '00',
#  '90',
#  'fungal',
#  'pneumonia',
#  '00',
#  '90',
#  'klebsiella',
#  '00',
#  '90',
#  'legionella',
#  '00',
#  '90',
#  'mers',
#  '00',
#  '90',
#  'finding',
#  '00',
#  '89',
#  '10',
#  '1',
#  'pneumocystis',
#  '00',
#  '90',
#  'pneumonia',
#  '00',
#  '5',
#  '10',
#  '85',
#  'sars',
#  '00',
#  '90',
#  'streptococcus',
#  '00',
#  '90',
#  'viral',
#  'pneumonia',
#  '00',
#  '9',
#  '10',
#  '81',
#  'lung',
#  'bounding',
#  'boxesannotationsimageannotation_ai_lung_bounding_boxesjson',
#  'contributed',
#  'andrew',
#  'gough',
#  'imageannotationai',
#  'inchttpswwwimageannotationaicovid19',
#  'pneumonia',
#  'severity',
#  'scoresannotationscovidseverityscorescsv',
#  'paper',
#  'predicting',
#  'covid19',
#  'pneumonia',
#  'severity',
#  'chest',
#  'xray',
#  'deep',
#  'learning',
#  'httparxivorgabs200511856',
#  'generated',
#  'lung',
#  'segmentationsannotationslungvaemasks',
#  'paper',
#  'lung',
#  'segmentation',
#  'chest',
#  'xrays',
#  'using',
#  'variational',
#  'data',
#  'imputationhttpsarxivorgabs200510052',
#  'contribute',
#  'submit',
#  'data',
#  'directly',
#  'project',
#  'view',
#  'research',
#  'protocolhttpsdocsgooglecomdocumentd14b7cou98yhycj2jwokznchtn5y6mi9bgjefv2dxot0edit',
#  'contact',
#  'u',
#  'start',
#  'process',
#  'extract',
#  'image',
#  'publication',
#  'help',
#  'identify',
#  'publication',
#  'already',
#  'included',
#  'using',
#  'github',
#  'issue',
#  'doi',
#  'listed',
#  'metadata',
#  'file',
#  'searchable',
#  'database',
#  'covid19',
#  'paper',
#  'herehttpswwwwhointemergenciesdiseasesnovelcoronavirus2019globalresearchonnovelcoronavirus2019ncov',
#  'nonsearchable',
#  'one',
#  'requires',
#  'download',
#  'herehttpspagessemanticscholarorgcoronavirusresearch',
#  'submit',
#  'data',
#  'site',
#  'scrape',
#  'data',
#  'httpsradiopaediaorg',
#  'license',
#  'cc',
#  'byncsa',
#  'httpswwwsirmorgcategorysenzacategoriacovid19',
#  'httpswwweuroradorg',
#  'license',
#  'cc',
#  'byncsa',
#  'httpscoronacasesorg',
#  'preferred',
#  'ct',
#  'scan',
#  'license',
#  'apache',
#  '20',
#  'provide',
#  'bounding',
#  'boxmasks',
#  'detection',
#  'problematic',
#  'region',
#  'image',
#  'already',
#  'collected',
#  'see',
#  'schemamdschemamd',
#  'information',
#  'metadata',
#  'schema',
#  'format',
#  'chest',
#  'xray',
#  'dcm',
#  'jpg',
#  'png',
#  'preferred',
#  'ct',
#  'nifti',
#  'gzip',
#  'format',
#  'preferred',
#  'also',
#  'dcms',
#  'please',
#  'contact',
#  'question',
#  'background',
#  'context',
#  'covid19',
#  'pandemic',
#  'want',
#  'improve',
#  'prognostic',
#  'prediction',
#  'triage',
#  'manage',
#  'patient',
#  'care',
#  'data',
#  'first',
#  'step',
#  'developing',
#  'diagnosticprognostic',
#  'tool',
#  'exist',
#  'large',
#  'public',
#  'datasets',
#  'typical',
#  'chest',
#  'xrays',
#  'nih',
#  'wang',
#  '2017',
#  'spain',
#  'bustos',
#  '2019',
#  'stanford',
#  'irvin',
#  '2019',
#  'mit',
#  'johnson',
#  '2019',
#  'indiana',
#  'university',
#  'demnerfushman',
#  '2016',
#  'collection',
#  'covid19',
#  'chest',
#  'xrays',
#  'ct',
#  'scan',
#  'designed',
#  'used',
#  'computational',
#  'analysis',
#  '2019',
#  'novel',
#  'coronavirus',
#  'covid19',
#  'present',
#  'several',
#  'unique',
#  'feature',
#  'fang',
#  '2020httpspubsrsnaorgdoi101148radiol2020200432',
#  'ai',
#  '2020httpspubsrsnaorgdoi101148radiol2020200642',
#  'diagnosis',
#  'confirmed',
#  'using',
#  'polymerase',
#  'chain',
#  'reaction',
#  'pcr',
#  'infected',
#  'patient',
#  'pneumonia',
#  'may',
#  'present',
#  'chest',
#  'xray',
#  'computed',
#  'tomography',
#  'ct',
#  'image',
#  'pattern',
#  'moderately',
#  'characteristic',
#  'human',
#  'eye',
#  'ng',
#  '2020httpspubsrsnaorgdoi101148ryct2020200034',
#  'late',
#  'january',
#  'chinese',
#  'team',
#  'published',
#  'paper',
#  'detailing',
#  'clinical',
#  'paraclinical',
#  'feature',
#  'covid19',
#  'reported',
#  'patient',
#  'present',
#  'abnormality',
#  'chest',
#  'ct',
#  'image',
#  'bilateral',
#  'involvement',
#  'huang',
#  '2020httpswwwthelancetcomjournalslancetarticlepiis0140673620301835fulltext',
#  'bilateral',
#  'multiple',
#  'lobular',
#  'subsegmental',
#  'area',
#  'consolidation',
#  'constitute',
#  'typical',
#  'finding',
#  'chest',
#  'ct',
#  'image',
#  'intensive',
#  'care',
#  'unit',
#  'icu',
#  'patient',
#  'admission',
#  'huang',
#  '2020httpswwwthelancetcomjournalslancetarticlepiis0140673620301835fulltext',
#  'comparison',
#  'nonicu',
#  'patient',
#  'show',
#  'bilateral',
#  'groundglass',
#  'opacity',
#  'subsegmental',
#  'area',
#  'consolidation',
#  'chest',
#  'ct',
#  'image',
#  'huang',
#  '2020httpswwwthelancetcomjournalslancetarticlepiis0140673620301835fulltext',
#  'patient',
#  'later',
#  'chest',
#  'ct',
#  'image',
#  'display',
#  'bilateral',
#  'groundglass',
#  'opacity',
#  'resolved',
#  'consolidation',
#  'huang',
#  '2020httpswwwthelancetcomjournalslancetarticlepiis0140673620301835fulltext',
#  'goal',
#  'goal',
#  'use',
#  'image',
#  'develop',
#  'ai',
#  'based',
#  'approach',
#  'predict',
#  'understand',
#  'infection',
#  'group',
#  'work',
#  'release',
#  'model',
#  'using',
#  'open',
#  'source',
#  'chester',
#  'ai',
#  'radiology',
#  'assistant',
#  'platformhttpsmlmedorgtoolsxray',
#  'task',
#  'follows',
#  'using',
#  'chest',
#  'xray',
#  'ct',
#  'preference',
#  'xray',
#  'input',
#  'predict',
#  'task',
#  'healthy',
#  'v',
#  'pneumonia',
#  'prototype',
#  'already',
#  'implemented',
#  'chesterhttpsmlmedorgtoolsxray',
#  '74',
#  'auc',
#  'validation',
#  'study',
#  'herehttpsarxivorgabs200202497',
#  'bacterial',
#  'v',
#  'viral',
#  'v',
#  'covid19',
#  'pneumonia',
#  'relevant',
#  'enough',
#  'clinical',
#  'workflow',
#  'prognosticseverity',
#  'prediction',
#  'survival',
#  'need',
#  'intubation',
#  'need',
#  'supplemental',
#  'oxygen',
#  'expected',
#  'outcome',
#  'tool',
#  'impact',
#  'would',
#  'give',
#  'physician',
#  'edge',
#  'allow',
#  'act',
#  'confidence',
#  'wait',
#  'analysis',
#  'radiologist',
#  'digital',
#  'second',
#  'opinion',
#  'confirm',
#  'assessment',
#  'patient',
#  'condition',
#  'also',
#  'tool',
#  'provide',
#  'quantitative',
#  'score',
#  'consider',
#  'use',
#  'study',
#  'data',
#  'impact',
#  'image',
#  'data',
#  'linked',
#  'clinically',
#  'relevant',
#  'attribute',
#  'public',
#  'dataset',
#  'designed',
#  'ml',
#  'enable',
#  'parallel',
#  'development',
#  'tool',
#  'rapid',
#  'local',
#  'validation',
#  'model',
#  'furthermore',
#  'data',
#  'used',
#  'completely',
#  'different',
#  'task',
#  'contact',
#  'pi',
#  'joseph',
#  'paul',
#  'cohen',
#  'postdoctoral',
#  'fellow',
#  'mila',
#  'university',
#  'montrealhttpsjosephpcohencom',
#  'initial',
#  'result',
#  'docscovidxrayumappng',
#  'citation',
#  'paper',
#  'availabe',
#  'herehttpsarxivorgabs200311597',
#  'joseph',
#  'paul',
#  'cohen',
#  'paul',
#  'morrison',
#  'lan',
#  'dao',
#  'covid19',
#  'image',
#  'data',
#  'collection',
#  'arxiv200311597',
#  '2020',
#  'httpsgithubcomieee8023covidchestxraydataset',
#  'articlecohen2020covid',
#  'titlecovid19',
#  'image',
#  'data',
#  'collection',
#  'authorjoseph',
#  'paul',
#  'cohen',
#  'paul',
#  'morrison',
#  'lan',
#  'dao',
#  'journalarxiv',
#  '200311597',
#  'urlhttpsgithubcomieee8023covidchestxraydataset',
#  'year2020']

# %%
df['number_of_words'] = df.clean_lemmatized.apply(lambda x: len(tokenizer.tokenize(x)))
df['num_unique_words'] = df.clean_lemmatized.apply(lambda x: len(set(tokenizer.tokenize(x))))
df.head()
# Out:
#    index                              repo          language  \
# 0      1    tokyo-metropolitan-gov/covid19               Vue
# 1      3   covid19india/covid19india-react        JavaScript
# 2      5  ieee8023/covid-chestxray-dataset  Jupyter Notebook
# 3      7             ahmadawais/corona-cli        JavaScript
# 4      8  ExpDev07/coronavirus-tracker-api            Python
#
#                                      readme_contents  \
# 0  # 東京都 新型コロナウイルス感染症対策サイト\n\n![](https://github....
# 1  <p align="center">\n<img src="https://lh3.goog...
# 2  \n#### 🛑 Note: please do not claim diagnostic ...
# 3  <h4 align="center">\n    <a href="https://gith...
# 4  <h1 align="center">\n    Coronavirus Tracker A...
#
#                                          basic_clean  \
# 0    \n\nhttpsgithubcomtokyometropolitangovcovid1...
# 1  \n\n\n\n\n  heres our data api\n \n\n setup\n\...
# 2  \n  note please do not claim diagnostic perfor...
# 3  \n    \n        \n    \n    \n    \n\ntrack th...
# 4  \n    coronavirus tracker api\n\n\nprovides up...
#
#                                          clean_tokes  \
# 0  [httpsgithubcomtokyometropolitangovcovid19work...
# 1  [heres, our, data, api, setup, npm, i, npm, st...
# 2  [note, please, do, not, claim, diagnostic, per...
# 3  [track, the, coronavirus, disease, covid19, or...
# 4  [coronavirus, tracker, api, provides, uptodate...
#
#                                           lemmatized  \
# 0  httpsgithubcomtokyometropolitangovcovid19workf...
# 1  here our data api setup npm i npm start mainta...
# 2  note please do not claim diagnostic performanc...
# 3  track the coronavirus disease covid19 or the n...
# 4  coronavirus tracker api provides uptodate data...
#
#                                     clean_lemmatized  link_counts  \
# 0  httpsgithubcomtokyometropolitangovcovid19workf...         1822
# 1  data api setup npm npm start maintainer jeremy...         1822
# 2  note please claim diagnostic performance model...         1822
# 3  track coronavirus disease covid19 novel corona...         1822
# 4  coronavirus tracker api provides uptodate data...         1822
#
#    number_of_words  num_unique_words
# 0               19                19
# 1               50                47
# 2              663               384
# 3              823               413
# 4             1032               480

# %%
tokenizer.tokenize(df.clean_lemmatized.iloc[6])
# Out:
# ['reverse',
#  'engineering',
#  'coronavirus',
#  'sarscov2',
#  'start',
#  'coronapycoronapy',
#  'thought_balloon',
#  'background',
#  'project',
#  'applies',
#  'technique',
#  'reverse',
#  'engineeringhttpsenwikipediaorgwikireverse_engineering',
#  'understand',
#  'sarscov2httpsenwikipediaorgwikisevere_acute_respiratory_syndrome_coronavirus_2',
#  'virus',
#  'goal',
#  'simply',
#  'build',
#  'understanding',
#  'virus',
#  'first',
#  'principle',
#  'biology',
#  'v',
#  'software',
#  'biological',
#  'system',
#  'fundamentally',
#  'information',
#  'processing',
#  'systemshttpsenwikipediaorgwikiinformation_processor',
#  'perfect',
#  'analogy',
#  'software',
#  'provides',
#  'useful',
#  'framework',
#  'thinking',
#  'biology',
#  'table',
#  'provides',
#  'rough',
#  'outline',
#  'analogy',
#  'microscope',
#  'biology',
#  'computer',
#  'software',
#  'note',
#  'nucleotidehttpsenwikipediaorgwikinucleotide',
#  'bytehttpsenwikipediaorgwikibyte',
#  'genomehttpsenwikipediaorgwikigenome',
#  'bytecodehttpsenwikipediaorgwikibytecode',
#  'translationhttpsenwikipediaorgwikitranslation_biology',
#  'disassemblyhttpsenwikipediaorgwikidisassembler',
#  '3',
#  'byte',
#  'wide',
#  'instruction',
#  'set',
#  'arbitrary',
#  'reading',
#  'frameshttpsenwikipediaorgwikireading_frame',
#  'proteinhttpsenwikipediaorgwikiprotein',
#  'functionhttpsenwikipediaorgwikifunction_computer_science',
#  'polyprotein',
#  'function',
#  'multiple',
#  'piece',
#  'protein',
#  'secondary',
#  'structurehttpsenwikipediaorgwikiprotein_secondary_structure',
#  'basic',
#  'blockshttpsenwikipediaorgwikibasic_block',
#  '80',
#  'accuracy',
#  'predictionhttpsenwikipediaorgwikiprotein_structure_predictionsecondary_structure',
#  'protein',
#  'tertiary',
#  'structurehttpsenwikipediaorgwikiprotein_tertiary_structure',
#  'seems',
#  'like',
#  'hard',
#  'one',
#  'predict',
#  'httpsjournalsplosorgplosonearticleid101371journalpone0205819',
#  'quaternary',
#  'structurehttpsenwikipediaorgwikiprotein_quaternary_structure',
#  'compiled',
#  'function',
#  'inlininghttpsenwikipediaorgwikiinline_expansion',
#  'httpsenwikipediaorgwikiproteine28093protein_interaction_prediction',
#  'genehttpsenwikipediaorgwikigene',
#  'libraryhttpsenwikipediaorgwikilibrary_computing',
#  'bacteria',
#  'statically',
#  'linked',
#  'virus',
#  'dynamically',
#  'linked',
#  'transcriptionhttpsenwikipediaorgwikitranscription_biology',
#  'loadinghttpsenwikipediaorgwikiloader_computing',
#  'protein',
#  'structure',
#  'predictionhttpsenwikipediaorgwikiprotein_structure_prediction',
#  'library',
#  'identificationhttpswwwhexrayscomproductsidatechflirtin_depth',
#  'genome',
#  'analysishttpsenwikipediaorgwikigenomicsgenome_analysis',
#  'static',
#  'analysishttpsenwikipediaorgwikistatic_program_analysis',
#  'molecular',
#  'dynamicshttpsenwikipediaorgwikimolecular_dynamics',
#  'simulation',
#  'protein',
#  'foldinghttpsenwikipediaorgwikiprotein_folding',
#  'dynamic',
#  'analysishttpsenwikipediaorgwikidynamic_program_analysis',
#  'simulation',
#  'doesnt',
#  'seem',
#  'work',
#  'yet',
#  'constrained',
#  'tooling',
#  'compute',
#  'equivalent',
#  'executionhttpsenwikipediaorgwikiexecution_computing',
#  'reverse',
#  'engineering',
#  'cad',
#  'format',
#  'run',
#  'like',
#  'fpga',
#  'code',
#  'serial',
#  'execution',
#  'fpga',
#  'reverse',
#  'engineering',
#  'tool',
#  'wrench',
#  'progress',
#  'downloading',
#  'sarscov2',
#  'genome',
#  'genbankhttpswwwncbinlmnihgovgenbank',
#  'nih',
#  'genetic',
#  'sequence',
#  'database',
#  'annotated',
#  'collection',
#  'publicly',
#  'available',
#  'dna',
#  'rna',
#  'sequence',
#  'sarscov2',
#  'sequence',
#  'available',
#  'genbank',
#  'downloaded',
#  'download_sequencespydownload_sequencespy',
#  'translating',
#  'rna',
#  'protein',
#  'libpylibpy',
#  'contains',
#  'function',
#  'translate',
#  'convert',
#  'rna',
#  'sequence',
#  'chain',
#  'amino',
#  'acidshttpsenwikipediaorgwikiamino_acid',
#  'function',
#  'used',
#  'coronapycoronapy',
#  'annotating',
#  'function',
#  'translate',
#  'function',
#  'used',
#  'coronapycoronapy',
#  'identify',
#  'annotate',
#  'function',
#  'protein',
#  'encoded',
#  'genome',
#  'folding',
#  'protein',
#  'openmmhttpopenmmorg',
#  'toolkit',
#  'used',
#  'molecular',
#  'simulation',
#  'protein',
#  'folding',
#  'foldpyfoldpy',
#  'bulb',
#  'work',
#  'done',
#  'automatic',
#  'extraction',
#  'gene',
#  'different',
#  'coronaviruses',
#  'good',
#  'multisequence',
#  'compare',
#  'tool',
#  'molecular',
#  'dynamic',
#  'secondary',
#  'structure',
#  'prediction',
#  'orf1a',
#  'question',
#  'open',
#  'question',
#  'orf1ab',
#  'cleaved',
#  'polypeptide',
#  'predict',
#  'sequence',
#  'researcher',
#  'know',
#  'guess',
#  'orf1ab',
#  'cleaves',
#  'nsp3',
#  'nsp5',
#  'httpswwwpnasorgcontentpnas103155717fullpdf',
#  'protein',
#  'immune',
#  'system',
#  'responding',
#  'spike',
#  'nucleocapsid',
#  'httpwwwcmiustceducn13193pdf',
#  'people',
#  'already',
#  'immune',
#  'exposure',
#  'coronavirus',
#  'find',
#  'furin',
#  'cleavage',
#  'site',
#  'spike',
#  'glycoprotein',
#  'might',
#  'prra',
#  'httpswwwsciencedirectcomsciencearticlepiis0166354220300528',
#  'use',
#  'prop',
#  'pitou',
#  'predict',
#  'httpsenwikipediaorgwikifurin',
#  'similar',
#  'coronaviruses',
#  'cause',
#  'cold',
#  'either',
#  'sars',
#  'mers',
#  'alpha',
#  'httpsenwikipediaorgwikihuman_coronavirus_229e',
#  'simpler',
#  'though',
#  'target',
#  'apn',
#  'httpsenwikipediaorgwikihuman_coronavirus_nl63',
#  'target',
#  'ace2',
#  'httpswwwncbinlmnihgovnuccoremg772808',
#  'beta',
#  'httpsenwikipediaorgwikihuman_coronavirus_oc43',
#  'target',
#  'neu5ac',
#  'httpswwwncbinlmnihgovpmcarticlespmc2095096pdfjidmm17330pdf',
#  'specifically',
#  'similar',
#  'n',
#  'protein',
#  'oc43',
#  'sars',
#  'v1',
#  'sars',
#  'v2',
#  'httpsenwikipediaorgwikihuman_coronavirus_hku1',
#  'target',
#  'neu5ac',
#  'merscov',
#  'sarscov',
#  'sarscov2',
#  'add',
#  'phosphate',
#  'group',
#  'n',
#  'protein',
#  'kinase',
#  'droplet',
#  'testing',
#  'test',
#  'work',
#  'based',
#  'httpsenwikipediaorgwikireverse_transcription_polymerase_chain_reaction',
#  'usa',
#  'httpswwwfdagovmedia134922download',
#  'selected',
#  'region',
#  'virus',
#  'nucleocapsid',
#  'n',
#  'gene',
#  '28286283082833228358',
#  '29163291872921029230',
#  'httpsbiosearchtechabigcontentiov1staticcoa_kitncovpp11000_lotno143503',
#  'south',
#  'korea',
#  'httpwwwkogenecokrengabout_usnewslistbodyphph_gcodeboardh_code7po_no288',
#  'e',
#  'gene',
#  'detection',
#  'coronavirus',
#  'specific',
#  'rdrp',
#  'detection',
#  'homemade',
#  'test',
#  'isolation',
#  'viral',
#  'rna',
#  'matter',
#  'httpswwwqiagencomusproductsdiagnosticsandclinicalresearchsampleprocessingqiaampviralrnaminikitorderinginformation',
#  'primer',
#  'probe',
#  'detect',
#  'sarscov2',
#  'httpswwwbiosearchtechcomproductspcrkitsandreagentspathogendetection2019ncovcdcprobeandprimerkitforsarscov2',
#  'wouldnt',
#  'need',
#  'using',
#  'nanopore',
#  'sequencer',
#  'nanopore',
#  'minion',
#  'rtqpcr',
#  'master',
#  'mix',
#  'pcr',
#  'httpswwwthermofishercomordercatalogproducta15300a15300',
#  'probably',
#  'wouldnt',
#  'need',
#  'using',
#  'nanopore',
#  'sequencer',
#  'one',
#  'httpswwwchaibiocomcoronavirus',
#  'open',
#  'qpcr',
#  'understand',
#  'httpswwwchaibiocomopenqpcr',
#  'fam',
#  'hex',
#  'fluorophores',
#  'pill',
#  'possible',
#  'treatment',
#  'prophylactic',
#  'warning',
#  'disclaimer',
#  'information',
#  'repository',
#  'informational',
#  'purpose',
#  'medical',
#  'advice',
#  'hydroxychloroquine',
#  'zinc',
#  'zinc',
#  'block',
#  'rdrp',
#  'httpsjviasmorgcontent9121e0075417',
#  'similar',
#  'hep',
#  'e',
#  'rdrp',
#  'httpswwwncbinlmnihgovpubmed21079686',
#  'chloroquine',
#  'zinc',
#  'ionophore',
#  'allows',
#  'zinc',
#  'cell',
#  'httpswwwncbinlmnihgovpmcarticlespmc4182877',
#  'rdrphttpsenwikipediaorgwikirnadependent_rna_polymerase',
#  'inhibitor',
#  'favipiravir',
#  'prodrug',
#  'favipiravirrtp',
#  'adenosine',
#  'analog',
#  'remdesivir',
#  'prodrug',
#  'gs441524',
#  'galidesivir',
#  'homemade',
#  'dna',
#  'vaccine',
#  'httpssiaskynetbaclkgmcmx4ncp47wwoojf0lu666vlet5hrwpwvtqzpjea',
#  'based',
#  'injecting',
#  'dna',
#  'plasmid',
#  'express',
#  'spike',
#  'protein',
#  'book',
#  'resource',
#  'coronavirusrelated',
#  'publication',
#  'chapter',
#  '4',
#  'coronavirus',
#  'pathogenesis',
#  'httpswwwsciencedirectcomsciencearticlepiib9780123858856000092',
#  'httpswwwfuturemedicinecomdoipdf102217fvl20180008',
#  'httpswwwsciencedirectcomsciencearticlepiis2095177920302045',
#  'httpkorkinlaborgwuhan',
#  'biology',
#  'textbook',
#  'molecular',
#  'biology',
#  'cell',
#  'class',
#  'better',
#  'test',
#  'httpsocwmiteducoursesbiology7012introductiontobiologyfall2004indexhtm',
#  'suspected',
#  'better',
#  'lecture',
#  'httpsocwmiteducoursesbiology7014introductorybiologyspring2005indexhtm',
#  'basic',
#  'httpswwwkhanacademyorgsciencebiology',
#  'bioinformatics',
#  'nextstrain',
#  'httpsnextstrainorgncov',
#  'httpsgithubcomnextstrainncov',
#  'httpsgithubcomnextstrainaugur',
#  'httpsbiopythonorg',
#  'httpswwwredditcomrbioinformaticscomments191ykrresources_for_learning_bioinformatics',
#  'httpsenwikipediaorgwikibioinformatics',
#  'epidemic',
#  'modeling',
#  'httpsgabgohgithubiocovidindexhtml',
#  'httpepidemicforecastingorg']

# %%
vectorized_df = vectorized_df.join(df[['link_counts', 'number_of_words', 'num_unique_words']], how='left')

# %%
vectorized_df
# Out:
#           00       002        01        02  04162020        05  05132020  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.630423  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.014731  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.024351  0.000000  0.024351
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.048331  0.016084  0.048331  0.000000  0.012083  0.000000
# 25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#     05262020  06012020       0no  ...   zhidong     zhong      zhou      zinc  \
# 0   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.022515  ...  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  ...  0.019723  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.150628
# 7   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.006085  0.000000
# 8   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 15  0.024351  0.024351  0.000000  ...  0.000000  0.048702  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000  0.000000
#
#     zingming      zoom       zum  link_counts  number_of_words  \
# 0   0.000000  0.000000  0.000000         1822               19
# 1   0.000000  0.000000  0.000000         1822               50
# 2   0.000000  0.000000  0.000000         1822              663
# 3   0.000000  0.000000  0.000000         1822              823
# 4   0.000000  0.000000  0.000000         1822             1032
# 5   0.000000  0.000000  0.000000         1822             1015
# 6   0.000000  0.000000  0.000000         1822              464
# 7   0.000000  0.000000  0.006085         1822             4259
# 8   0.000000  0.108472  0.000000         1822              301
# 9   0.000000  0.011377  0.000000         1822             1541
# 10  0.091685  0.000000  0.000000         1822              150
# 11  0.000000  0.000000  0.000000         1822              305
# 12  0.000000  0.000000  0.000000         1822              994
# 13  0.000000  0.000000  0.000000         1822              660
# 14  0.000000  0.000000  0.000000         1822                5
# 15  0.000000  0.000000  0.000000         1822              743
# 16  0.000000  0.000000  0.000000         1822              604
# 17  0.000000  0.000000  0.000000         1822              364
# 18  0.000000  0.000000  0.000000         1822               40
# 19  0.000000  0.000000  0.000000         1822               52
# 20  0.000000  0.000000  0.000000         1822              224
# 21  0.000000  0.000000  0.000000         1822              376
# 22  0.000000  0.000000  0.000000         1822              273
# 23  0.000000  0.000000  0.000000         1822              240
# 24  0.000000  0.000000  0.000000         1822             2858
# 25  0.000000  0.000000  0.000000         1822               23
#
#     num_unique_words
# 0                 19
# 1                 47
# 2                384
# 3                413
# 4                480
# 5                629
# 6                345
# 7               1821
# 8                255
# 9                717
# 10               137
# 11               219
# 12               452
# 13               296
# 14                 5
# 15               398
# 16               431
# 17               204
# 18                31
# 19                41
# 20               154
# 21               156
# 22               176
# 23               160
# 24               734
# 25                20
#
# [26 rows x 5391 columns]
